# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %%
drug_useByAge = pd.read_csv('drugUseByAge.csv', index_col=0, parse_dates=True)
df = pd.DataFrame(drug_useByAge)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
drug_useByAge.iloc[:, 1:10].plot()
